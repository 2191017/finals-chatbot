# %%
#import necessary libraries
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
import random

# %%
#create array for words, classes and documents and import intents file
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data = open('data/intents.json').read()
intents = json.loads(data)

# %% [markdown]
# ## Data Preprocessing

# %%
#tokenize each sentence and create a list of classes for the tags
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)

        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmatization and data cleaning
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

# sort classes
classes = sorted(list(set(classes)))

# documents = combination between patterns and intents
print (len(documents), "documents")

# classes = intents
print (len(classes), "classes", classes)

# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 268 documents
# 71 classes ['Consultation', 'Depression symptoms', 'Mental_Health', 'about', 'angry', 'anxiety', 'anxiety_causes', 'anxiety_disorders', 'anxiety_symptoms', 'bad', 'bipolar_causes', 'bipolar_disorder', 'bipolar_symptoms', 'bipolar_treatment', 'causes', 'definition', 'depression', 'depression prevention', 'do', 'eating_causes', 'eating_disorder', 'eating_symptoms', 'eating_treatment', 'fav', 'find_help', 'funny', 'generalized_disorder', 'good', 'goodbye', 'greetings', 'hectic', 'help', 'initiate', 'joke', 'life', 'name', 'name1', 'noanswer', 'obsessive_disorder', 'okay', 'panic_attacks', 'panic_disorder', 'personality_causes', 'personality_disorders', 'personality_symptoms', 'personality_treatment', 'phobias', 'post_disorder', 'post_symptoms', 'professional_types', 'recover', 'relationship', 'relax', 'right_professional', 'sad', 'scary_things', 'schizophrenia', 'situations', 'social', 'social_phobia', 'specific_phobia', 'steps', 'talk', 'tasks', 'thanks', 'tips', 'treat', 'treatement_options', 'treatment_tips', 'what_causes', 'worthiness']
# 250 unique lemmatized words ["'m", "'s", ',', 'a', 'ability', 'about', 'affect', 'ahhhhh', 'am', 'angry', 'anxiety', 'anxious', 'any', 'anymore', 'appears', 'are', 'ask', 'at', 'attack', 'available', 'awesome', 'be', 'become', 'begin', 'best', 'better', 'between', 'bipolar', 'burnt', 'busy', 'but', 'buy', 'bye', 'can', 'care', 'cause', 'change', 'cheating', 'commit', 'commitment', 'consultation', 'contact', 'could', 'day', 'death', 'define', 'depressed', 'depression', 'describe', 'diagnosed', 'did', 'difference', 'different', 'disorder', 'do', 'doctor', 'doe', 'down', 'drink', 'eat', 'eating', 'everything', 'exam', 'factor', 'fatigue', 'favour', 'feature', 'feel', 'feeling', 'few', 'find', 'fine', 'fix', 'followed', 'for', 'friend', 'from', 'funny', 'generalized', 'get', 'getting', 'girlfriend', 'give', 'going', 'good', 'great', 'hand', 'happy', 'hard', 'haroo', 'have', 'having', 'health', 'hectic', 'hell', 'hello', 'help', 'helpful', 'helping', 'here', 'hey', 'hi', 'holla', 'hopeless', 'how', 'i', 'if', 'ill', 'illness', 'in', 'incase', 'increased', 'information', 'initiate', 'initiating', 'interest', 'involved', 'is', 'it', 'joke', 'keep', 'know', 'later', 'laugh', 'lboyfriend', 'lead', 'life', 'like', 'looking', 'lost', 'lot', 'loved', 'mad', 'made', 'make', 'man', 'me', 'mean', 'meaning', 'medicine', 'meeting', 'meh', 'mental', 'mentally', 'method', 'mind', 'more', 'motivation', 'my', 'myself', "n't", 'name', 'need', 'no', 'not', 'obsessive-compulsive', 'of', 'okay', 'on', 'one', 'option', 'or', 'out', 'outlook', 'panic', 'people', 'personality', 'phobia', 'please', 'possible', 'post-traumatic', 'present', 'prevention', 'problem', 'professional', 'purpose', 'question', 'really', 'recover', 'relationship', 'relax', 'relaxation', 'right', 'sad', 'scary', 'schizophrenia', 'science', 'scream', 'see', 'set', 'should', 'sing', 'situation', 'sleep', 'so', 'social', 'some', 'someone', 'something', 'specific', 'start', 'step', 'stress', 'stressed', 'study', 'such', 'suffering', 'suggestion', 'support', 'survey', 'symptom', 'take', 'talk', 'tell', 'thank', 'thanks', 'thankyou', 'that', 'the', 'there', 'thing', 'think', 'tip', 'to', 'today', 'treat', 'treated', 'treatment', 'trouble', 'trust', 'type', 'unable', 'up', 'wa', 'want', 'wassup', 'weight', 'well', 'what', 'who', 'with', 'work', 'worst', 'worthiness', 'worthy', 'wow', 'yaw', 'you', 'your', 'yourself']

# %%
# create training data array
training = []

# create an empty array for our output
output_empty = [0] * len(classes)

# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]

    # create our bag of words array if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# %%
# shuffle features and turn into np.array
random.shuffle(training)
training = np.array(training)

# create train and test data wherein X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
# Out:
# <ipython-input-6-e1694c840fc4>:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model using Stochastic gradient descent with Nesterov accelerated gradient
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model', hist)
print("model created")
# Out:
# C:\Users\lois\anaconda3\lib\site-packages\keras\optimizer_v2\gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/200
# 54/54 [==============================] - 4s 7ms/step - loss: 4.2810 - accuracy: 0.0224
# Epoch 2/200
# 54/54 [==============================] - 0s 7ms/step - loss: 4.1983 - accuracy: 0.0672
# Epoch 3/200
# 54/54 [==============================] - 0s 6ms/step - loss: 4.1380 - accuracy: 0.0560
# Epoch 4/200
# 54/54 [==============================] - 0s 5ms/step - loss: 4.0671 - accuracy: 0.0858
# Epoch 5/200
# 54/54 [==============================] - 0s 5ms/step - loss: 3.9579 - accuracy: 0.0858
# Epoch 6/200
# 54/54 [==============================] - 0s 5ms/step - loss: 3.7992 - accuracy: 0.0933
# Epoch 7/200
# 54/54 [==============================] - 0s 4ms/step - loss: 3.6841 - accuracy: 0.1306
# Epoch 8/200
# 54/54 [==============================] - 0s 2ms/step - loss: 3.4824 - accuracy: 0.1493
# Epoch 9/200
# 54/54 [==============================] - 0s 2ms/step - loss: 3.2131 - accuracy: 0.1866
# Epoch 10/200
# 54/54 [==============================] - 0s 2ms/step - loss: 3.1016 - accuracy: 0.1903
# Epoch 11/200
# 54/54 [==============================] - 0s 2ms/step - loss: 2.9556 - accuracy: 0.2276
# Epoch 12/200
# 54/54 [==============================] - 0s 2ms/step - loss: 2.7394 - accuracy: 0.2612
# Epoch 13/200
# 54/54 [==============================] - 0s 2ms/step - loss: 2.6370 - accuracy: 0.2612
# Epoch 14/200
# 54/54 [==============================] - 0s 2ms/step - loss: 2.5269 - accuracy: 0.3284
# Epoch 15/200
# 54/54 [==============================] - 0s 2ms/step - loss: 2.3298 - accuracy: 0.3396
# Epoch 16/200
# 54/54 [==============================] - 0s 2ms/step - loss: 2.1385 - accuracy: 0.4030
# Epoch 17/200
# 54/54 [==============================] - 0s 2ms/step - loss: 2.0831 - accuracy: 0.4328
# Epoch 18/200
# 54/54 [==============================] - 0s 2ms/step - loss: 2.0532 - accuracy: 0.3881
# Epoch 19/200
# 54/54 [==============================] - 0s 2ms/step - loss: 1.9716 - accuracy: 0.4440
# Epoch 20/200
# 54/54 [==============================] - 0s 2ms/step - loss: 1.8719 - accuracy: 0.4590
# Epoch 21/200
200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.7258 - accuracy: 0.7537
# Epoch 66/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6015 - accuracy: 0.7873
# Epoch 67/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.7279 - accuracy: 0.7873
# Epoch 68/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.7649 - accuracy: 0.7612
# Epoch 69/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.7552 - accuracy: 0.7351
# Epoch 70/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6333 - accuracy: 0.7799
# Epoch 71/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6238 - accuracy: 0.7724
# Epoch 72/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6638 - accuracy: 0.7575
# Epoch 73/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5920 - accuracy: 0.7724
# Epoch 74/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.7307 - accuracy: 0.7612
# Epoch 75/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5567 - accuracy: 0.8209
# Epoch 76/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5461 - accuracy: 0.8060
# Epoch 77/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6282 - accuracy: 0.7948
# Epoch 78/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6463 - accuracy: 0.7724
# Epoch 79/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6429 - accuracy: 0.7948
# Epoch 80/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6345 - accuracy: 0.7724
# Epoch 81/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5851 - accuracy: 0.8246
# Epoch 82/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6624 - accuracy: 0.7799
# Epoch 83/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6769 - accuracy: 0.8097
# Epoch 84/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6170 - accuracy: 0.7910
# Epoch 85/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6039 - accuracy: 0.8060
# Epoch 86/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5580 - accuracy: 0.8209
# Epoch 87/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6515 - accuracy: 0.7761
# Epoch 88/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6603 - accuracy: 0.7948
# Epoch 89/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6994 - accuracy: 0.7799
# Epoch 90/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6040 - accuracy: 0.7948
# Epoch 91/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4828 - accuracy: 0.8358
# Epoch 92/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6385 - accuracy: 0.7687
# Epoch 93/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5746 - accuracy: 0.7799
# Epoch 94/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6896 - accuracy: 0.7985
# Epoch 95/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5474 - accuracy: 0.8022
# Epoch 96/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4865 - accuracy: 0.8321
# Epoch 97/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5069 - accuracy: 0.8172
# Epoch 98/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5495 - accuracy: 0.8209
# Epoch 99/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5842 - accuracy: 0.8022
# Epoch 100/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5120 - accuracy: 0.8097
# Epoch 101/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6016 - accuracy: 0.7948
# Epoch 102/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6118 - accuracy: 0.8022
# Epoch 103/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4716 - accuracy: 0.8396
# Epoch 104/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.7427 - accuracy: 0.7537
# Epoch 105/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5880 - accuracy: 0.8209
# Epoch 106/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6663 - accuracy: 0.7799
# Epoch 107/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5637 - accuracy: 0.8060
# Epoch 108/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5990 - accuracy: 0.8209
# Epoch 109/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5569 - accuracy: 0.8209
# Epoch 110/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6110 - accuracy: 0.7910
# Epoch 111/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4599 - accuracy: 0.8470
# Epoch 112/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5057 - accuracy: 0.8358
# Epoch 113/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5302 - accuracy: 0.8022
# Epoch 114/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4926 - accuracy: 0.8209
# Epoch 115/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6466 - accuracy: 0.8209
# Epoch 116/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5529 - accuracy: 0.8134
# Epoch 117/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6074 - accuracy: 0.7724
# Epoch 118/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5448 - accuracy: 0.8172
# Epoch 119/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4064 - accuracy: 0.8507
# Epoch 120/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5549 - accuracy: 0.7910
# Epoch 121/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4536 - accuracy: 0.8470
# Epoch 122/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5063 - accuracy: 0.8358
# Epoch 123/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5985 - accuracy: 0.7910
# Epoch 124/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5236 - accuracy: 0.8284
# Epoch 125/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5477 - accuracy: 0.7836
# Epoch 126/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5780 - accuracy: 0.7985
# Epoch 127/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6291 - accuracy: 0.7948
# Epoch 128/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5102 - accuracy: 0.8172
# Epoch 129/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5040 - accuracy: 0.8284
# Epoch 130/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5966 - accuracy: 0.8172
# Epoch 131/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5449 - accuracy: 0.8284
# Epoch 132/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4806 - accuracy: 0.8284
# Epoch 133/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4489 - accuracy: 0.8582
# Epoch 134/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5169 - accuracy: 0.8172
# Epoch 135/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5290 - accuracy: 0.8060
# Epoch 136/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5682 - accuracy: 0.8246
# Epoch 137/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5810 - accuracy: 0.7985
# Epoch 138/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4363 - accuracy: 0.8321
# Epoch 139/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5507 - accuracy: 0.8246
# Epoch 140/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5229 - accuracy: 0.8284
# Epoch 141/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4689 - accuracy: 0.8507
# Epoch 142/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4409 - accuracy: 0.8209
# Epoch 143/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3874 - accuracy: 0.8545
# Epoch 144/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5297 - accuracy: 0.7948
# Epoch 145/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4884 - accuracy: 0.8246
# Epoch 146/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4817 - accuracy: 0.8097
# Epoch 147/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4955 - accuracy: 0.8433
# Epoch 148/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6430 - accuracy: 0.7948
# Epoch 149/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5835 - accuracy: 0.8022
# Epoch 150/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4313 - accuracy: 0.8470
# Epoch 151/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5314 - accuracy: 0.8134
# Epoch 152/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4788 - accuracy: 0.8209
# Epoch 153/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4081 - accuracy: 0.8358
# Epoch 154/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5313 - accuracy: 0.8321
# Epoch 155/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5398 - accuracy: 0.8060
# Epoch 156/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5393 - accuracy: 0.8209
# Epoch 157/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4100 - accuracy: 0.8582
# Epoch 158/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5210 - accuracy: 0.8209
# Epoch 159/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4343 - accuracy: 0.8284
# Epoch 160/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5072 - accuracy: 0.8321
# Epoch 161/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4648 - accuracy: 0.8246
# Epoch 162/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5435 - accuracy: 0.8172
# Epoch 163/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4229 - accuracy: 0.8657
# Epoch 164/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5108 - accuracy: 0.8246
# Epoch 165/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5066 - accuracy: 0.8358
# Epoch 166/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4318 - accuracy: 0.8246
# Epoch 167/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4389 - accuracy: 0.8246
# Epoch 168/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5006 - accuracy: 0.8470
# Epoch 169/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4641 - accuracy: 0.8470
# Epoch 170/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4715 - accuracy: 0.8134
# Epoch 171/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4563 - accuracy: 0.8582
# Epoch 172/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4176 - accuracy: 0.8470
# Epoch 173/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5325 - accuracy: 0.8060
# Epoch 174/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5820 - accuracy: 0.8097
# Epoch 175/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5163 - accuracy: 0.8284
# Epoch 176/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5221 - accuracy: 0.8321
# Epoch 177/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5776 - accuracy: 0.8022
# Epoch 178/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3875 - accuracy: 0.8694
# Epoch 179/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5109 - accuracy: 0.8358
# Epoch 180/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5972 - accuracy: 0.7873
# Epoch 181/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5624 - accuracy: 0.8097
# Epoch 182/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4658 - accuracy: 0.8433
# Epoch 183/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5007 - accuracy: 0.8209
# Epoch 184/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4737 - accuracy: 0.8507
# Epoch 185/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5848 - accuracy: 0.8209
# Epoch 186/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4715 - accuracy: 0.8433
# Epoch 187/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4914 - accuracy: 0.8545
# Epoch 188/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4871 - accuracy: 0.8246
# Epoch 189/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5183 - accuracy: 0.8172
# Epoch 190/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4742 - accuracy: 0.8209
# Epoch 191/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5419 - accuracy: 0.7985
# Epoch 192/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4447 - accuracy: 0.8246
# Epoch 193/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5353 - accuracy: 0.8134
# Epoch 194/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3485 - accuracy: 0.8881
# Epoch 195/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5137 - accuracy: 0.8358
# Epoch 196/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5055 - accuracy: 0.8134
# Epoch 197/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4431 - accuracy: 0.8284
# Epoch 198/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5718 - accuracy: 0.8396
# Epoch 199/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5047 - accuracy: 0.8209
# Epoch 200/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4606 - accuracy: 0.8396
# INFO:tensorflow:Assets written to: chatbot_model\assets
# model created
